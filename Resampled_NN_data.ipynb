# %%
# !pip install update xarray 
# !pip install cmocean 
! pip install netcdf4
# ! pip install cftime
# ! pip install hdf5
# ! conda install cmocean --y
# ! pip install cartopy 
# ! pip install cmocean
# !apt-get -qq install update python-cartopy python3-cartopy
# !  pip install nc-time-axis
# ! pip install wget
# ! pip install matplotlib
#! pip install intake

! pip  install zarr
# ! pip install dask
# ! pip install tqdm
! pip install nc_time_axis
! pip install cmip6_preprocessing
! pip install gcsfs
# !apt-get -qq install python-cartopy python3-cartopy
# import cartopy

# !python -m pip install intake-esm
# Out:
# Collecting netcdf4
#   Downloading netCDF4-1.5.6-cp36-cp36m-manylinux2014_x86_64.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 8.4 MB/s
# Collecting cftime
#   Downloading cftime-1.4.1-cp36-cp36m-manylinux2014_x86_64.whl (316 kB)
#      |████████████████████████████████| 316 kB 63.9 MB/s
# Requirement already satisfied: numpy>=1.9 in /usr/local/lib/python3.6/site-packages (from netcdf4) (1.19.4)
# Installing collected packages: cftime, netcdf4
# Successfully installed cftime-1.4.1 netcdf4-1.5.6
# Collecting zarr
#   Using cached zarr-2.7.0-py3-none-any.whl (137 kB)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/site-packages (from zarr) (1.19.4)
# Collecting asciitree
#   Using cached asciitree-0.3.3.tar.gz (4.0 kB)
# Collecting numcodecs>=0.6.4
#   Downloading numcodecs-0.7.3-cp36-cp36m-manylinux2010_x86_64.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 5.8 MB/s
# Collecting fasteners
#   Using cached fasteners-0.16-py2.py3-none-any.whl (28 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.6/site-packages (from fasteners->zarr) (1.15.0)
# Building wheels for collected packages: asciitree
#   Building wheel for asciitree (setup.py) ... done
#   Created wheel for asciitree: filename=asciitree-0.3.3-py3-none-any.whl size=5036 sha256=cefbc861fd2007b6460b3253fcfd255e2902548e1b1296bc5efe795c16040e6c
#   Stored in directory: /root/.cache/pip/wheels/9d/b0/4a/2370154bc4a63b2ceec1670d3346840ff28bcbe49911f5df92
# Successfully built asciitree
# Installing collected packages: numcodecs, fasteners, asciitree, zarr
# Successfully installed asciitree-0.3.3 fasteners-0.16 numcodecs-0.7.3 zarr-2.7.0
# Collecting nc_time_axis
#   Using cached nc_time_axis-1.2.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: cftime in /usr/local/lib/python3.6/site-packages (from nc_time_axis) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/site-packages (from nc_time_axis) (1.19.4)
# Collecting matplotlib
#   Downloading matplotlib-3.3.4-cp36-cp36m-manylinux1_x86_64.whl (11.5 MB)
#      |████████████████████████████████| 11.5 MB 9.5 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/site-packages (from nc_time_axis) (1.15.0)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.2.0-cp36-cp36m-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 52.9 MB/s
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 4.1 MB/s
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp36-cp36m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 39.7 MB/s
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/site-packages (from matplotlib->nc_time_axis) (2.8.1)
# Installing collected packages: pyparsing, pillow, kiwisolver, cycler, matplotlib, nc-time-axis
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.3.4 nc-time-axis-1.2.0 pillow-8.2.0 pyparsing-2.4.7
# Collecting cmip6_preprocessing
#   Using cached cmip6_preprocessing-0.1.4-py2.py3-none-any.whl (13 kB)
# Installing collected packages: cmip6-preprocessing
# Successfully installed cmip6-preprocessing-0.1.4
# Collecting gcsfs
#   Using cached gcsfs-0.8.0-py2.py3-none-any.whl (23 kB)
# Collecting decorator
#   Downloading decorator-5.0.5-py3-none-any.whl (8.8 kB)
# Collecting fsspec>=0.8.0
#   Using cached fsspec-0.9.0-py3-none-any.whl (107 kB)
# Collecting ujson
#   Downloading ujson-4.0.2-cp36-cp36m-manylinux1_x86_64.whl (179 kB)
#      |████████████████████████████████| 179 kB 8.8 MB/s
# Collecting aiohttp
#   Downloading aiohttp-3.7.4.post0-cp36-cp36m-manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 9.0 MB/s
# Collecting google-auth-oauthlib
#   Downloading google_auth_oauthlib-0.4.4-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/site-packages (from gcsfs) (2.25.1)
# Collecting google-auth>=1.2
#   Downloading google_auth-1.28.0-py2.py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 47.6 MB/s
# Collecting importlib-metadata
#   Downloading importlib_metadata-3.10.0-py3-none-any.whl (14 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/site-packages (from google-auth>=1.2->gcsfs) (1.15.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.6/site-packages (from google-auth>=1.2->gcsfs) (52.0.0.post20210125)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 35.8 MB/s
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.1-py3-none-any.whl (12 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 3.8 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.6.3-cp36-cp36m-manylinux2014_x86_64.whl (293 kB)
#      |████████████████████████████████| 293 kB 38.0 MB/s
# Collecting attrs>=17.3.0
#   Downloading attrs-20.3.0-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 3.5 MB/s
# Collecting async-timeout<4.0,>=3.0
#   Using cached async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.1.0-cp36-cp36m-manylinux2014_x86_64.whl (141 kB)
#      |████████████████████████████████| 141 kB 48.1 MB/s
# Collecting typing-extensions>=3.6.5
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: chardet<5.0,>=2.0 in /usr/local/lib/python3.6/site-packages (from aiohttp->gcsfs) (4.0.0)
# Collecting idna-ssl>=1.0
#   Downloading idna-ssl-1.1.0.tar.gz (3.4 kB)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.6/site-packages (from idna-ssl>=1.0->aiohttp->gcsfs) (2.10)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 48.6 MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/site-packages (from requests->gcsfs) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.6/site-packages (from requests->gcsfs) (1.26.4)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Building wheels for collected packages: idna-ssl
#   Building wheel for idna-ssl (setup.py) ... done
#   Created wheel for idna-ssl: filename=idna_ssl-1.1.0-py3-none-any.whl size=3160 sha256=a5247aadc7b244ec755fbcdaabf07789f9e4cb946b0d046f343f005de1d8c7ac
#   Stored in directory: /root/.cache/pip/wheels/6a/f5/9c/f8331a854f7a8739cf0e74c13854e4dd7b1af11b04fe1dde13
# Successfully built idna-ssl
# Installing collected packages: pyasn1, zipp, typing-extensions, rsa, pyasn1-modules, oauthlib, multidict, cachetools, yarl, requests-oauthlib, importlib-metadata, idna-ssl, google-auth, attrs, async-timeout, ujson, google-auth-oauthlib, fsspec, decorator, aiohttp, gcsfs
# Successfully installed aiohttp-3.7.4.post0 async-timeout-3.0.1 attrs-20.3.0 cachetools-4.2.1 decorator-5.0.5 fsspec-0.9.0 gcsfs-0.8.0 google-auth-1.28.0 google-auth-oauthlib-0.4.4 idna-ssl-1.1.0 importlib-metadata-3.10.0 multidict-5.1.0 oauthlib-3.1.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.7.2 typing-extensions-3.7.4.3 ujson-4.0.2 yarl-1.6.3 zipp-3.4.1

# %%
# %matplotlib inline
import numpy as np
import gcsfs
import pandas as pd
import xarray as xr
import warnings
import matplotlib.pyplot as plt
# import intake_esm
# import cartopy
# from cartopy import util
# import cartopy.crs as ccrs
import zarr
import dask.array as da  
from dask.diagnostics import ProgressBar
from tqdm.autonotebook import tqdm
import nc_time_axis
import time


import cmip6_preprocessing
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from ipykernel import kernelapp as app

# %%
Data = xr.open_dataset('/content/global-reanalysis-NN_input_gridded_data.nc')


Data = Data.squeeze()
Data = Data.sel(time = slice(None, '2014'))


# NN = xr.Dataset(data_vars= dict(
#       mlotst = (['time','y','x'],data.mlotst.values),
#       thetao = (['time','y','x'],data.thetao.values),
#       so = (['time','y','x',],data.so.values)), coords = dict(
#           lat = (['y','x'], lat),
#           lon = (['y','x'], lon),
#           time = data.time.values))
# NN
Data
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 205, longitude: 421, time: 264)
# Coordinates:
#     depth      float32 0.494025
#   * latitude   (latitude) float32 45.0 45.083332 45.166668 ... 61.916668 62.0
#   * time       (time) datetime64[ns] 1993-01-16T12:00:00 ... 2014-12-16T12:00:00
#   * longitude  (longitude) float32 -155.0 -154.91667 ... -120.083336 -120.0
# Data variables:
#     mlotst     (time, latitude, longitude) float32 ...
#     thetao     (time, latitude, longitude) float32 ...
#     so         (time, latitude, longitude) float32 ...
# Attributes:
#     title:                         Monthly mean fields for product GLOBAL_REA...
#     references:                    http://marine.copernicus.eu
#     credit:                        E.U. Copernicus Marine Service Information...
#     licence:                       http://marine.copernicus.eu/services-portf...
#     contact:                       servicedesk.cmems@mercator-ocean.eu
#     producer:                      CMEMS - Global Monitoring and Forecasting ...
#     institution:                   Mercator Ocean
#     Conventions:                   CF-1.6
#     area:                          GLOBAL
#     product:                       GLOBAL_REANALYSIS_001_030
#     dataset:                       global-reanalysis-001-030-monthly
#     source:                        MERCATOR GLORYS12V1
#     product_user_manual:           http://marine.copernicus.eu/documents/PUM/...
#     quality_information_document:  http://marine.copernicus.eu/documents/QUID...
#     _CoordSysBuilder:              ucar.nc2.dataset.conv.CF1Convention
#     comment:
#     history:                       Data extracted from dataset http://localho...

# %% [markdown]
# #Thatao

# %%
! pip install wget
import wget
! wget http://crd-esgf-drc.ec.gc.ca/thredds/fileServer/esgC_dataroot/AR6/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_199101-200012.nc
! wget http://crd-esgf-drc.ec.gc.ca/thredds/fileServer/esgC_dataroot/AR6/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_200101-201012.nc
! wget http://crd-esgf-drc.ec.gc.ca/thredds/fileServer/esgC_dataroot/AR6/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_201101-201412.nc
# Out:
# Requirement already satisfied: wget in /usr/local/lib/python3.6/site-packages (3.2)
# --2021-04-06 09:07:18--  http://crd-esgf-drc.ec.gc.ca/thredds/fileServer/esgC_dataroot/AR6/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_199101-200012.nc
# Resolving crd-esgf-drc.ec.gc.ca (crd-esgf-drc.ec.gc.ca)... 205.189.10.92
# Connecting to crd-esgf-drc.ec.gc.ca (crd-esgf-drc.ec.gc.ca)|205.189.10.92|:80... connected.
# HTTP request sent, awaiting response... 200 200
# Length: 1009820505 (963M) [application/x-netcdf]
# Saving to: ‘thetao_Omon_CanESM5_historical_r1i1p1f1_gn_199101-200012.nc’
#
# thetao_Omon_CanESM5 100%[===================>] 963.04M  15.1MB/s    in 78s
#
# 2021-04-06 09:08:36 (12.4 MB/s) - ‘thetao_Omon_CanESM5_historical_r1i1p1f1_gn_199101-200012.nc’ saved [1009820505/1009820505]
#
# --2021-04-06 09:08:36--  http://crd-esgf-drc.ec.gc.ca/thredds/fileServer/esgC_dataroot/AR6/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_200101-201012.nc
# Resolving crd-esgf-drc.ec.gc.ca (crd-esgf-drc.ec.gc.ca)... 205.189.10.92
# Connecting to crd-esgf-drc.ec.gc.ca (crd-esgf-drc.ec.gc.ca)|205.189.10.92|:80... connected.
# HTTP request sent, awaiting response... 200 200
# Length: 1009667505 (963M) [application/x-netcdf]
# Saving to: ‘thetao_Omon_CanESM5_historical_r1i1p1f1_gn_200101-201012.nc’
#
# thetao_Omon_CanESM5 100%[===================>] 962.89M  11.7MB/s    in 71s
#
# 2021-04-06 09:09:48 (13.5 MB/s) - ‘thetao_Omon_CanESM5_historical_r1i1p1f1_gn_200101-201012.nc’ saved [1009667505/1009667505]
#
# --2021-04-06 09:09:48--  http://crd-esgf-drc.ec.gc.ca/thredds/fileServer/esgC_dataroot/AR6/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_201101-201412.nc
# Resolving crd-esgf-drc.ec.gc.ca (crd-esgf-drc.ec.gc.ca)... 205.189.10.92
# Connecting to crd-esgf-drc.ec.gc.ca (crd-esgf-drc.ec.gc.ca)|205.189.10.92|:80... connected.
# HTTP request sent, awaiting response... 200 200
# Length: 404837946 (386M) [application/x-netcdf]
# Saving to: ‘thetao_Omon_CanESM5_historical_r1i1p1f1_gn_201101-201412.nc’
#
# thetao_Omon_CanESM5 100%[===================>] 386.08M  28.0MB/s    in 27s
#
# 2021-04-06 09:10:15 (14.1 MB/s) - ‘thetao_Omon_CanESM5_historical_r1i1p1f1_gn_201101-201412.nc’ saved [404837946/404837946]

# %%
data = xr.open_dataset('/content/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_199101-200012.nc')
data1 =  xr.open_dataset('/content/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_200101-201012.nc')
data2 =  xr.open_dataset('/content/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_201101-201412.nc')



data.drop_dims('bnds')
data.drop_dims('vertices')

data1.drop_dims('bnds')
data1.drop_dims('vertices')

data2.drop_dims('bnds')
data2.drop_dims('vertices')

data = data.thetao.isel(lev = 0)
data1 = data1.thetao.isel(lev = 0)
data2 = data2.thetao.isel(lev = 0)


ds = xr.concat([data,data1,data2], dim ='time')
ds = ds.rename({'longitude':'lon', 'latitude':'lat'}) 
ds_out = xe.util.grid_global(1, 1)
regridder = xe.Regridder(ds, ds_out, 'bilinear', ignore_degenerate=True, reuse_weights=True, periodic=True)
thetao = regridder(ds)
thetao['time'] = thetao.indexes['time'].to_datetimeindex()
thetao = thetao.drop('lev')
# Out:
# Reuse existing file: bilinear_291x360_180x360_peri.nc
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: RuntimeWarning: Converting a CFTimeIndex with dates from a non-standard calendar, 'noleap', to a pandas.DatetimeIndex, which uses dates from the standard calendar.  This may lead to subtle errors in operations that depend on the length of time between dates.

# %%
lat = thetao.lat.values[:,0]
lon = thetao.lon.values[0,:]

C = xr.Dataset(data_vars= dict(
      thetao = (['time','lat','lon'],thetao.values)), coords = dict(
          lat = (['lat'], lat),
          lon = (['lon'], lon),
          time = thetao.time.values))
C
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 180, lon: 360, time: 288)
# Coordinates:
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -179.5 -178.5 -177.5 -176.5 ... 177.5 178.5 179.5
#   * time     (time) datetime64[ns] 1991-01-16T12:00:00 ... 2014-12-16T12:00:00
# Data variables:
#     thetao   (time, lat, lon) float64 nan nan nan nan ... -1.699 -1.699 -1.699

# %%
CanESM5_r1i1p1f1_thetao_resampled = C.thetao.interp(lat = Data.latitude.values
                                                    , lon = Data.longitude.values, time = Data.time.values )
CanESM5_r1i1p1f1_thetao_resampled
# Out:
# <xarray.DataArray 'thetao' (time: 264, lat: 205, lon: 421)>
# array([[[ 9.48013718,  9.48495921,  9.48978212, ...,         nan,
#                  nan,         nan],
#         [ 9.4313199 ,  9.43598817,  9.44065729, ...,         nan,
#                  nan,         nan],
#         [ 9.38250038,  9.38701489,  9.39153022, ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        [[ 9.25805292,  9.26095574,  9.26385908, ...,         nan,
#                  nan,         nan],
#         [ 9.21412985,  9.21682671,  9.21952407, ...,         nan,
#                  nan,         nan],
#         [ 9.17020477,  9.17269567,  9.17518703, ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        [[ 9.12958637,  9.13078224,  9.13197833, ...,         nan,
#                  nan,         nan],
#         [ 9.08398854,  9.08487781,  9.08576724, ...,         nan,
#                  nan,         nan],
#         [ 9.03838862,  9.03897128,  9.03955404, ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        ...,
#
#        [[13.41973772, 13.43633926, 13.45294384, ...,         nan,
#                  nan,         nan],
#         [13.33418908, 13.35107052, 13.36795506, ...,         nan,
#                  nan,         nan],
#         [13.24863652, 13.26579789, 13.2829624 , ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        [[11.66704465, 11.67844023, 11.6898379 , ...,         nan,
#                  nan,         nan],
#         [11.59305505, 11.60452552, 11.6159981 , ...,         nan,
#                  nan,         nan],
#         [11.51906206, 11.53060743, 11.54215491, ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        [[10.38368741, 10.38755229, 10.39141788, ...,         nan,
#                  nan,         nan],
#         [10.33549443, 10.33917091, 10.34284806, ...,         nan,
#                  nan,         nan],
#         [10.28729925, 10.29078732, 10.29427602, ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]]])
# Coordinates:
#   * lat      (lat) float32 45.0 45.083332 45.166668 ... 61.833332 61.916668 62.0
#   * lon      (lon) float32 -155.0 -154.91667 -154.83333 ... -120.083336 -120.0
#   * time     (time) datetime64[ns] 1993-01-16T12:00:00 ... 2014-12-16T12:00:00

# %% [markdown]
# #MLOTST

# %%
! wget http://crd-esgf-drc.ec.gc.ca/thredds/fileServer/esgC_dataroot/AR6/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/mlotst/gn/v20190429/mlotst_Omon_CanESM5_historical_r1i1p1f1_gn_185001-201412.nc

# %%
data = xr.open_dataset('/content/mlotst_Omon_CanESM5_historical_r1i1p1f1_gn_185001-201412.nc')


data =  data.drop_dims('bnds')
ds = data.drop_dims('vertices')


ds = ds.mlotst.rename({'longitude':'lon', 'latitude':'lat'}) 
ds_out = xe.util.grid_global(1, 1)
regridder = xe.Regridder(ds, ds_out, 'bilinear', ignore_degenerate=True, reuse_weights=True, periodic=True)
mlotst = regridder(ds)
mlotst['time'] = mlotst.indexes['time'].to_datetimeindex()
mlotst = mlotst.sel(time = slice('1900',None))
# Out:
# Reuse existing file: bilinear_291x360_180x360_peri.nc
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: RuntimeWarning: Converting a CFTimeIndex with dates from a non-standard calendar, 'noleap', to a pandas.DatetimeIndex, which uses dates from the standard calendar.  This may lead to subtle errors in operations that depend on the length of time between dates.
#   if sys.path[0] == '':

# %%
lat = mlotst.lat.values[:,0]
lon = mlotst.lon.values[0,:]

C = xr.Dataset(data_vars= dict(
      mlotst = (['time','lat','lon'],mlotst.values)), coords = dict(
          lat = (['lat'], lat),
          lon = (['lon'], lon),
          time = mlotst.time.values))
C
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 180, lon: 360, time: 1380)
# Coordinates:
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -179.5 -178.5 -177.5 -176.5 ... 177.5 178.5 179.5
#   * time     (time) datetime64[ns] 1900-01-16T12:00:00 ... 2014-12-16T12:00:00
# Data variables:
#     mlotst   (time, lat, lon) float64 nan nan nan nan ... 48.81 48.77 48.74

# %%
CanESM5_r1i1p1f1_mlotst_resampled = C.mlotst.interp(lat = Data.latitude.values
                                                    , lon = Data.longitude.values, time = Data.time.values )
CanESM5_r1i1p1f1_mlotst_resampled
# Out:
# <xarray.DataArray 'mlotst' (time: 264, lat: 205, lon: 421)>
# array([[[95.25756231, 95.18558582, 95.11359615, ...,         nan,
#                  nan,         nan],
#         [95.61086604, 95.54634366, 95.48180946, ...,         nan,
#                  nan,         nan],
#         [95.96418594, 95.90711801, 95.85003963, ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        [[97.60828165, 97.45330225, 97.29829447, ...,         nan,
#                  nan,         nan],
#         [98.34501258, 98.18179505, 98.01854764, ...,         nan,
#                  nan,         nan],
#         [99.08177723, 98.91032121, 98.73883378, ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        [[96.75360555, 96.70059547, 96.64757568, ...,         nan,
#                  nan,         nan],
#         [96.79732654, 96.74493717, 96.69253821, ...,         nan,
#                  nan,         nan],
#         [96.84104953, 96.78928091, 96.73750281, ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        ...,
#
#        [[46.36358764, 46.46398772, 46.56440618, ...,         nan,
#                  nan,         nan],
#         [46.43147744, 46.52811325, 46.62476676, ...,         nan,
#                  nan,         nan],
#         [46.49937036, 46.59224172, 46.6851301 , ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        [[73.87862757, 73.98574488, 74.09288179, ...,         nan,
#                  nan,         nan],
#         [73.96543978, 74.07291396, 74.18040783, ...,         nan,
#                  nan,         nan],
#         [74.05225595, 74.16008704, 74.26793787, ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        [[87.67074006, 87.76007389, 87.84942407, ...,         nan,
#                  nan,         nan],
#         [87.9880721 , 88.08666644, 88.18527883, ...,         nan,
#                  nan,         nan],
#         [88.30541868, 88.41327394, 88.52114895, ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]]])
# Coordinates:
#   * lat      (lat) float32 45.0 45.083332 45.166668 ... 61.833332 61.916668 62.0
#   * lon      (lon) float32 -155.0 -154.91667 -154.83333 ... -120.083336 -120.0
#   * time     (time) datetime64[ns] 1993-01-16T12:00:00 ... 2014-12-16T12:00:00

# %% [markdown]
# #OS

# %%
! wget http://crd-esgf-drc.ec.gc.ca/thredds/fileServer/esgC_dataroot/AR6/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/so/gn/v20190429/so_Omon_CanESM5_historical_r1i1p1f1_gn_199101-200012.nc
! wget http://crd-esgf-drc.ec.gc.ca/thredds/fileServer/esgC_dataroot/AR6/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/so/gn/v20190429/so_Omon_CanESM5_historical_r1i1p1f1_gn_200101-201012.nc
! wget http://crd-esgf-drc.ec.gc.ca/thredds/fileServer/esgC_dataroot/AR6/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/so/gn/v20190429/so_Omon_CanESM5_historical_r1i1p1f1_gn_201101-201412.nc
# Out:
# --2021-04-06 09:13:23--  http://crd-esgf-drc.ec.gc.ca/thredds/fileServer/esgC_dataroot/AR6/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/so/gn/v20190429/so_Omon_CanESM5_historical_r1i1p1f1_gn_199101-200012.nc
# Resolving crd-esgf-drc.ec.gc.ca (crd-esgf-drc.ec.gc.ca)... 205.189.10.92
# Connecting to crd-esgf-drc.ec.gc.ca (crd-esgf-drc.ec.gc.ca)|205.189.10.92|:80... connected.
# HTTP request sent, awaiting response... 200 200
# Length: 770557031 (735M) [application/x-netcdf]
# Saving to: ‘so_Omon_CanESM5_historical_r1i1p1f1_gn_199101-200012.nc’
#
# so_Omon_CanESM5_his 100%[===================>] 734.86M  43.9MB/s    in 21s
#
# 2021-04-06 09:13:44 (35.4 MB/s) - ‘so_Omon_CanESM5_historical_r1i1p1f1_gn_199101-200012.nc’ saved [770557031/770557031]
#
# --2021-04-06 09:13:44--  http://crd-esgf-drc.ec.gc.ca/thredds/fileServer/esgC_dataroot/AR6/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/so/gn/v20190429/so_Omon_CanESM5_historical_r1i1p1f1_gn_200101-201012.nc
# Resolving crd-esgf-drc.ec.gc.ca (crd-esgf-drc.ec.gc.ca)... 205.189.10.92
# Connecting to crd-esgf-drc.ec.gc.ca (crd-esgf-drc.ec.gc.ca)|205.189.10.92|:80... connected.
# HTTP request sent, awaiting response... 200 200
# Length: 769827517 (734M) [application/x-netcdf]
# Saving to: ‘so_Omon_CanESM5_historical_r1i1p1f1_gn_200101-201012.nc’
#
# so_Omon_CanESM5_his 100%[===================>] 734.16M  42.5MB/s    in 22s
#
# 2021-04-06 09:14:07 (32.7 MB/s) - ‘so_Omon_CanESM5_historical_r1i1p1f1_gn_200101-201012.nc’ saved [769827517/769827517]
#
# --2021-04-06 09:14:07--  http://crd-esgf-drc.ec.gc.ca/thredds/fileServer/esgC_dataroot/AR6/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/so/gn/v20190429/so_Omon_CanESM5_historical_r1i1p1f1_gn_201101-201412.nc
# Resolving crd-esgf-drc.ec.gc.ca (crd-esgf-drc.ec.gc.ca)... 205.189.10.92
# Connecting to crd-esgf-drc.ec.gc.ca (crd-esgf-drc.ec.gc.ca)|205.189.10.92|:80... connected.
# HTTP request sent, awaiting response... 200 200
# Length: 308721328 (294M) [application/x-netcdf]
# Saving to: ‘so_Omon_CanESM5_historical_r1i1p1f1_gn_201101-201412.nc’
#
# so_Omon_CanESM5_his 100%[===================>] 294.42M  15.1MB/s    in 23s
#
# 2021-04-06 09:14:30 (12.9 MB/s) - ‘so_Omon_CanESM5_historical_r1i1p1f1_gn_201101-201412.nc’ saved [308721328/308721328]

# %%
data = xr.open_dataset('/content/so_Omon_CanESM5_historical_r1i1p1f1_gn_199101-200012.nc')
data1 =  xr.open_dataset('/content/so_Omon_CanESM5_historical_r1i1p1f1_gn_200101-201012.nc')
data2 =  xr.open_dataset('/content/so_Omon_CanESM5_historical_r1i1p1f1_gn_201101-201412.nc')



data.drop_dims('bnds')
data.drop_dims('vertices')

data1.drop_dims('bnds')
data1.drop_dims('vertices')

data2.drop_dims('bnds')
data2.drop_dims('vertices')

data = data.so.isel(lev = 0)
data1 = data1.so.isel(lev = 0)
data2 = data2.so.isel(lev = 0)


ds = xr.concat([data,data1,data2], dim ='time')
ds = ds.rename({'longitude':'lon', 'latitude':'lat'}) 
ds_out = xe.util.grid_global(1, 1)
regridder = xe.Regridder(ds, ds_out, 'bilinear', ignore_degenerate=True, reuse_weights=True, periodic=True)
so = regridder(ds)
so['time'] = so.indexes['time'].to_datetimeindex()
so = so.drop('lev')
# Out:
# Reuse existing file: bilinear_291x360_180x360_peri.nc
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: RuntimeWarning: Converting a CFTimeIndex with dates from a non-standard calendar, 'noleap', to a pandas.DatetimeIndex, which uses dates from the standard calendar.  This may lead to subtle errors in operations that depend on the length of time between dates.

# %%
lat = so.lat.values[:,0]
lon = so.lon.values[0,:]

C = xr.Dataset(data_vars= dict(
      so = (['time','lat','lon'],so.values)), coords = dict(
          lat = (['lat'], lat),
          lon = (['lon'], lon),
          time = so.time.values))
C
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 180, lon: 360, time: 288)
# Coordinates:
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -179.5 -178.5 -177.5 -176.5 ... 177.5 178.5 179.5
#   * time     (time) datetime64[ns] 1991-01-16T12:00:00 ... 2014-12-16T12:00:00
# Data variables:
#     so       (time, lat, lon) float64 nan nan nan nan ... 31.19 31.19 31.19 31.2

# %%
CanESM5_r1i1p1f1_so_resampled = C.so.interp(lat = Data.latitude.values
                                                    , lon = Data.longitude.values, time = Data.time.values )
CanESM5_r1i1p1f1_so_resampled
# Out:
# <xarray.DataArray 'so' (time: 264, lat: 205, lon: 421)>
# array([[[33.18337024, 33.18145558, 33.17954056, ...,         nan,
#                  nan,         nan],
#         [33.17174501, 33.1698971 , 33.16804886, ...,         nan,
#                  nan,         nan],
#         [33.16011925, 33.1583381 , 33.15655662, ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        [[33.24500695, 33.2423681 , 33.23972877, ...,         nan,
#                  nan,         nan],
#         [33.23213975, 33.22950862, 33.22687701, ...,         nan,
#                  nan,         nan],
#         [33.21927196, 33.21664855, 33.21402467, ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        [[33.25871768, 33.25558162, 33.252445  , ...,         nan,
#                  nan,         nan],
#         [33.24430766, 33.24111678, 33.23792532, ...,         nan,
#                  nan,         nan],
#         [33.22989699, 33.22665128, 33.22340498, ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        ...,
#
#        [[32.9795578 , 32.97843914, 32.97732028, ...,         nan,
#                  nan,         nan],
#         [32.96663628, 32.96550754, 32.9643786 , ...,         nan,
#                  nan,         nan],
#         [32.95371417, 32.95257535, 32.95143632, ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        [[33.03812333, 33.03738888, 33.03665429, ...,         nan,
#                  nan,         nan],
#         [33.02601728, 33.02539571, 33.02477403, ...,         nan,
#                  nan,         nan],
#         [33.01391067, 33.01340199, 33.01289322, ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        [[33.10872657, 33.10596356, 33.10320006, ...,         nan,
#                  nan,         nan],
#         [33.09512845, 33.09239011, 33.08965127, ...,         nan,
#                  nan,         nan],
#         [33.08152972, 33.07881604, 33.07610187, ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]]])
# Coordinates:
#   * lat      (lat) float32 45.0 45.083332 45.166668 ... 61.833332 61.916668 62.0
#   * lon      (lon) float32 -155.0 -154.91667 -154.83333 ... -120.083336 -120.0
#   * time     (time) datetime64[ns] 1993-01-16T12:00:00 ... 2014-12-16T12:00:00

# %%
CanESM5_r1i1p1f1_historical_resampled = xr.Dataset( data_vars= dict(
    so =CanESM5_r1i1p1f1_so_resampled,
    mltost = CanESM5_r1i1p1f1_mlotst_resampled,
    thetao = CanESM5_r1i1p1f1_thetao_resampled ))
CanESM5_r1i1p1f1_historical_resampled= CanESM5_r1i1p1f1_historical_resampled.rename({'lat' : 'latitude','lon' : 'longitude'})
CanESM5_r1i1p1f1_historical_resampled = CanESM5_r1i1p1f1_historical_resampled.assign_coords(depth = data.lev.values )
CanESM5_r1i1p1f1_historical_resampled.to_netcdf('CanESM5_r1i1p1f1_historical_resampled.nc')

# %%
CanESM5_r1i1p1f1_historical_resampled
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 205, longitude: 421, time: 264)
# Coordinates:
#   * latitude   (latitude) float32 45.0 45.083332 45.166668 ... 61.916668 62.0
#   * longitude  (longitude) float32 -155.0 -154.91667 ... -120.083336 -120.0
#   * time       (time) datetime64[ns] 1993-01-16T12:00:00 ... 2014-12-16T12:00:00
#     depth      float64 3.047
# Data variables:
#     so         (time, latitude, longitude) float64 33.18 33.18 33.18 ... nan nan
#     mltost     (time, latitude, longitude) float64 95.26 95.19 95.11 ... nan nan
#     thetao     (time, latitude, longitude) float64 9.48 9.485 9.49 ... nan nan

# %%
Data
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 205, longitude: 421, time: 264)
# Coordinates:
#     depth      float32 0.494025
#   * latitude   (latitude) float32 45.0 45.083332 45.166668 ... 61.916668 62.0
#   * time       (time) datetime64[ns] 1993-01-16T12:00:00 ... 2014-12-16T12:00:00
#   * longitude  (longitude) float32 -155.0 -154.91667 ... -120.083336 -120.0
# Data variables:
#     mlotst     (time, latitude, longitude) float32 ...
#     thetao     (time, latitude, longitude) float32 ...
#     so         (time, latitude, longitude) float32 ...
# Attributes:
#     title:                         Monthly mean fields for product GLOBAL_REA...
#     references:                    http://marine.copernicus.eu
#     credit:                        E.U. Copernicus Marine Service Information...
#     licence:                       http://marine.copernicus.eu/services-portf...
#     contact:                       servicedesk.cmems@mercator-ocean.eu
#     producer:                      CMEMS - Global Monitoring and Forecasting ...
#     institution:                   Mercator Ocean
#     Conventions:                   CF-1.6
#     area:                          GLOBAL
#     product:                       GLOBAL_REANALYSIS_001_030
#     dataset:                       global-reanalysis-001-030-monthly
#     source:                        MERCATOR GLORYS12V1
#     product_user_manual:           http://marine.copernicus.eu/documents/PUM/...
#     quality_information_document:  http://marine.copernicus.eu/documents/QUID...
#     _CoordSysBuilder:              ucar.nc2.dataset.conv.CF1Convention
#     comment:
#     history:                       Data extracted from dataset http://localho...
